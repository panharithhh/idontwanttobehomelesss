# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("keosaly/wildkhmerst-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 8.47G/8.47G [24:24<00:00, 6.21MB/s]
# Extracting files...
# Path to dataset files: /Users/cheapanharith/.cache/kagglehub/datasets/keosaly/wildkhmerst-dataset/versions/1
